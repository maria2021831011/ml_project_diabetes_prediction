# %% [markdown]
# <a href="https://colab.research.google.com/github/maria2021831011/ml_project_diabetes_prediction/blob/main/ml_project_diabetics_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/diabetes_prediction_dataset.csv')

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.describe(include='all')
# Out:
#         gender            age  hypertension  heart_disease smoking_history  \
# count   100000  100000.000000  100000.00000  100000.000000          100000
# unique       3            NaN           NaN            NaN               6
# top     Female            NaN           NaN            NaN         No Info
# freq     58552            NaN           NaN            NaN           35816
# mean       NaN      41.885856       0.07485       0.039420             NaN
# std        NaN      22.516840       0.26315       0.194593             NaN
# min        NaN       0.080000       0.00000       0.000000             NaN
# 25%        NaN      24.000000       0.00000       0.000000             NaN
# 50%        NaN      43.000000       0.00000       0.000000             NaN
# 75%        NaN      60.000000       0.00000       0.000000             NaN
# max        NaN      80.000000       1.00000       1.000000             NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.hist(figsize=(20, 15), color='skyblue', edgecolor='black')
plt.suptitle("Feature Distributions ", fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20, 8))
df.boxplot()
# Out:
# <Axes: >

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x="blood_glucose_level", y="bmi", hue="diabetes")
plt.title("Blood Glucose Level vs BMI")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(25, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Value Map", fontsize=16)
plt.xticks(rotation=45)
plt.show()
